# %%
import pandas as pd
import numpy as np
import warnings
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_absolute_percentage_error
warnings.filterwarnings('ignore')

# %%
data = pd.read_csv("C:/Users/ibuba/Kuliah/Dataset/UMR INDONESIA.csv", delimiter=';')
data
# Out:
#     TAHUN      UMR  INFLASI  JUMLAH PENDUDUK  ANGKATAN KERJA    BEKERJA  \
# 0    1997   135000     0.11        204000000        89230978   85047007
# 1    1998   150900     0.78        207000000        92337801   87292541
# 2    1999   175400     0.02        211000000        94847178   88816859
# 3    2000   216500     0.09        214000000        95650961   89837730
# 4    2001   290500     0.13        217000000        98812448   90807417
# 5    2002   362700     0.10        220000000       100779270   91647166
# 6    2003   414700     0.05        223000000       102750092   92810791
# 7    2004   458500     0.06        225000000       103973387   93722036
# 8    2005   507697     0.17        228000000       105857653   93958387
# 9    2006   602702     0.07        231000000       106388935   95456935
# 10   2007   672480     0.07        234000000       109941359   99930217
# 11   2008   745709     0.11        237000000       111947265  102552750
# ...

# %%
data.dtypes
# Out:
# TAHUN                    int64
# UMR                      int64
# INFLASI                float64
# JUMLAH PENDUDUK          int64
# ANGKATAN KERJA           int64
# BEKERJA                  int64
# PENGANGGURAN             int64
# PERTUMBUHAN EKONOMI    float64
# dtype: object

# %%
data.describe()
# Out:
#              TAHUN           UMR    INFLASI  JUMLAH PENDUDUK  ANGKATAN KERJA  \
# count    26.000000  2.600000e+01  26.000000     2.600000e+01    2.600000e+01
# mean   2009.500000  1.159755e+06   0.090000     2.415769e+08    1.150686e+08
# std       7.648529  8.804764e+05   0.145904     2.223902e+07    1.588136e+07
# min    1997.000000  1.350000e+05   0.010000     2.040000e+08    8.923098e+07
# 25%    2003.250000  4.256500e+05   0.030000     2.235000e+08    1.030559e+08
# 50%    2009.500000  8.751770e+05   0.055000     2.425000e+08    1.149655e+08
# 75%    2015.750000  1.945950e+06   0.087500     2.605000e+08    1.246778e+08
# max    2022.000000  2.672371e+06   0.780000     2.750000e+08    1.470320e+08
#
#             BEKERJA  PENGANGGURAN  PERTUMBUHAN EKONOMI
# count  2.600000e+01  2.600000e+01            26.000000
# mean   1.069811e+08  8.049265e+06             0.048846
# std    1.576009e+07  1.831055e+06             0.019251
# ...

# %%
# Data Train dan Label
dt = data.iloc[:,:-1]
label = data.iloc[:,-1]
display("Data Train :", dt)
display("Data Label :", label)
# Out:
# 'Data Train :'
#     TAHUN      UMR  INFLASI  JUMLAH PENDUDUK  ANGKATAN KERJA    BEKERJA  \
# 0    1997   135000     0.11        204000000        89230978   85047007
# 1    1998   150900     0.78        207000000        92337801   87292541
# 2    1999   175400     0.02        211000000        94847178   88816859
# 3    2000   216500     0.09        214000000        95650961   89837730
# 4    2001   290500     0.13        217000000        98812448   90807417
# 5    2002   362700     0.10        220000000       100779270   91647166
# 6    2003   414700     0.05        223000000       102750092   92810791
# 7    2004   458500     0.06        225000000       103973387   93722036
# 8    2005   507697     0.17        228000000       105857653   93958387
# 9    2006   602702     0.07        231000000       106388935   95456935
# 10   2007   672480     0.07        234000000       109941359   99930217
# 11   2008   745709     0.11        237000000       111947265  102552750
# ...

# %%
# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(dt, label, test_size=0.2, random_state=42)

# Inisialisasi model regresi linear
model = LinearRegression()

# Latih model
model.fit(X_train, y_train)

# Prediksi berdasarkan data testing
y_pred = model.predict(X_test)

# Hasil model dan evaluasi
r2 = r2_score(y_test, y_pred)
def adjusted_r2(r2, n, p):
    return 1 - (1 - r2) * (n - 1) / (n - p - 1)

adj_r2 = adjusted_r2(r2, X_test.shape[0], X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("Koefisien regresi:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R-squared:", r2)
print("Adjusted R-squared:", adj_r2)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Percentage Error:", mean_absolute_percentage_error(y_test, y_pred))
# Out:
# Koefisien regresi: [-5.94487929e-03 -5.04371940e-08 -2.14673363e-02  4.39558584e-09
#   2.36539834e-08 -2.41905531e-08 -2.24286796e-08]
# Intercept: 11.036940872668922
# Mean Squared Error: 0.0006053616091482351
# R-squared: -2.352771989128686
# Adjusted R-squared: 9.381929972821714
# Mean Absolute Error: 0.014798006710089384
# Root Mean Squared Error: 0.02460409740568093
# Mean Absolute Percentage Error: 0.22190253462256582

# %%
data
# Out:
#     TAHUN      UMR  INFLASI  JUMLAH PENDUDUK  ANGKATAN KERJA    BEKERJA  \
# 0    1997   135000     0.11        204000000        89230978   85047007
# 1    1998   150900     0.78        207000000        92337801   87292541
# 2    1999   175400     0.02        211000000        94847178   88816859
# 3    2000   216500     0.09        214000000        95650961   89837730
# 4    2001   290500     0.13        217000000        98812448   90807417
# 5    2002   362700     0.10        220000000       100779270   91647166
# 6    2003   414700     0.05        223000000       102750092   92810791
# 7    2004   458500     0.06        225000000       103973387   93722036
# 8    2005   507697     0.17        228000000       105857653   93958387
# 9    2006   602702     0.07        231000000       106388935   95456935
# 10   2007   672480     0.07        234000000       109941359   99930217
# 11   2008   745709     0.11        237000000       111947265  102552750
# ...

# %%
# Membuat kolom dummy 'TAHUN PEMILU' berdasarkan tahun krisis
dt['TAHUN PEMILU'] = [1 if year in [1999, 2004, 2009, 2014, 2019] else 0 for year in data['TAHUN']]
dt
# Out:
#     TAHUN      UMR  INFLASI  JUMLAH PENDUDUK  ANGKATAN KERJA    BEKERJA  \
# 0    1997   135000     0.11        204000000        89230978   85047007
# 1    1998   150900     0.78        207000000        92337801   87292541
# 2    1999   175400     0.02        211000000        94847178   88816859
# 3    2000   216500     0.09        214000000        95650961   89837730
# 4    2001   290500     0.13        217000000        98812448   90807417
# 5    2002   362700     0.10        220000000       100779270   91647166
# 6    2003   414700     0.05        223000000       102750092   92810791
# 7    2004   458500     0.06        225000000       103973387   93722036
# 8    2005   507697     0.17        228000000       105857653   93958387
# 9    2006   602702     0.07        231000000       106388935   95456935
# 10   2007   672480     0.07        234000000       109941359   99930217
# 11   2008   745709     0.11        237000000       111947265  102552750
# ...

# %%
# Split data menjadi training dan testing
X_train, X_test, y_train, y_test = train_test_split(dt, label, test_size=0.2, random_state=42)

# Latih model
model.fit(X_train, y_train)

# Prediksi berdasarkan data testing
y_pred = model.predict(X_test)

# Hasil model dan evaluasi
r2 = r2_score(y_test, y_pred)
def adjusted_r2(r2, n, p):
    return 1 - (1 - r2) * (n - 1) / (n - p - 1)

adj_r2 = adjusted_r2(r2, X_test.shape[0], X_test.shape[1])
rmse = np.sqrt(mean_squared_error(y_test, y_pred))

print("Koefisien regresi:", model.coef_)
print("Intercept:", model.intercept_)
print("Mean Squared Error:", mean_squared_error(y_test, y_pred))
print("R-squared:", r2)
print("Adjusted R-squared:", adj_r2)
print("Mean Absolute Error:", mean_absolute_error(y_test, y_pred))
print("Root Mean Squared Error:", rmse)
print("Mean Absolute Percentage Error:", mean_absolute_percentage_error(y_test, y_pred))
# Out:
# Koefisien regresi: [-4.12324930e-03 -5.19833514e-08 -2.52200021e-02  3.80074746e-09
#   2.10122052e-08 -2.15196712e-08 -2.00695545e-08 -3.25659479e-03]
# Intercept: 7.5223369695794515
# Mean Squared Error: 0.0005532421644520205
# R-squared: -2.0641104492727274
# Adjusted R-squared: 6.1068507487878785
# Mean Absolute Error: 0.014306715415007012
# Root Mean Squared Error: 0.023521100409037425
# Mean Absolute Percentage Error: 0.21977628344613112
